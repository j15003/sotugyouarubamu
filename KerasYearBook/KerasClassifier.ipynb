# %%
#! -*- coding: utf-8 -*-
import glob
import numpy as np
import shutil

from keras.preprocessing.image import load_img, img_to_array, array_to_img
from keras.preprocessing.image import random_rotation, random_shift, random_zoom
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dense
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.models import Sequential
from keras.models import model_from_json
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.utils import np_utils

import matplotlib.pyplot as plt
# %matplotlib inline

FileNames = ["gami.npy", "kaoru.npy", "soeda.npy","reiya.npy","mattyan.npy","kasuya.npy"]
ClassNames = ["gomi","kaoru", "soeda", "reiya","mattyan","kasuya"]
hw = {"height":32, "width":32}        # リストではなく辞書型 中かっこで囲む


################################
###### 画像データの前処理 ######
################################
def PreProcess(dirname, filename, var_amount=3):
    num = 0
    arrlist = []
    files = glob.glob(dirname + "/*.jpg")

    for imgfile in files:
        img = load_img(imgfile, target_size=(hw["height"], hw["width"]))    # 画像ファイルの読み込み
        array = img_to_array(img) / 255                                     # 画像ファイルのnumpy化
        arrlist.append(array)                 # numpy型データをリストに追加
        for i in range(var_amount-1):
            arr2 = array
            arr2 = random_rotation(arr2, rg=360)
            arrlist.append(arr2)              # numpy型データをリストに追加
        num += 1

    nplist = np.array(arrlist)
    np.save(filename, nplist)
    print(">> " + dirname + "から" + str(num) + "個のファイル読み込み成功")


################################
######### モデルの構築 #########
################################
def BuildCNN(ipshape=(32, 32, 3), num_classes=3):
    model = Sequential()

    model.add(Conv2D(24, 3, padding='same', input_shape=ipshape))
    model.add(Activation('relu'))

    model.add(Conv2D(48, 3))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))

    model.add(Conv2D(96, 3, padding='same'))
    model.add(Activation('relu'))

    model.add(Conv2D(96, 3))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy',
                  optimizer=adam,
                  metrics=['accuracy'])
    return model


################################
############# 学習 #############
################################
def Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9):
    X_TRAIN_list = []; Y_TRAIN_list = []; X_TEST_list = []; Y_TEST_list = [];
    target = 0
    for filename in FileNames :
        data = np.load(filename)          # 画像のnumpyデータを読み込み
        trnum = data.shape[0] - tsnum
        X_TRAIN_list += [data[i] for i in range(trnum)]          # 画像データ
        Y_TRAIN_list += [target] * trnum                         # 分類番号
        X_TEST_list  += [data[i] for i in range(trnum, trnum+tsnum)]          # 学習しない画像データ
        Y_TEST_list  += [target] * tsnum;                                     # 学習しない分類番号
        target += 1

    X_TRAIN = np.array(X_TRAIN_list + X_TEST_list)    # 連結
    Y_TRAIN = np.array(Y_TRAIN_list + Y_TEST_list)    # 連結
    print(">> 学習サンプル数 : ", X_TRAIN.shape)
    y_train = np_utils.to_categorical(Y_TRAIN, target)    # 自然数をベクトルに変換
    valrate = tsnum * target * 1.0 / X_TRAIN.shape[0]

    # 学習率の変更
    class Schedule(object):
        def __init__(self, init=0.001):      # 初期値定義
            self.init = init
        def __call__(self, epoch):           # 現在値計算
            lr = self.init
            for i in range(1, epoch+1):
                lr *= learn_schedule
            return lr

    def get_schedule_func(init):
        return Schedule(init)

    lrs = LearningRateScheduler(get_schedule_func(0.001))
    mcp = ModelCheckpoint(filepath='best.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    model = BuildCNN(ipshape=(X_TRAIN.shape[1], X_TRAIN.shape[2], X_TRAIN.shape[3]), num_classes=target)

    print(">> 学習開始")
    hist = model.fit(X_TRAIN, y_train,
                     batch_size=batch_size,
                     verbose=1,
                     epochs=nb_epoch,
                     validation_split=valrate,
                     callbacks=[lrs, mcp])

    json_string = model.to_json()
    json_string += '##########' + str(ClassNames)
    open('model.json', 'w').write(json_string)
    model.save_weights('last.hdf5')
    
    #acc, val_accのプロット
    plt.plot(hist.history["acc"], label="acc", ls="-", marker="o")
    plt.plot(hist.history["val_acc"], label="val_acc", ls="-", marker="x")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(loc="best")
    plt.show()


################################
########## 試行・実験 ##########
################################
def TestProcess(imgname):
    modelname_text = open("model.json").read()
    json_strings = modelname_text.split('##########')
    textlist = json_strings[1].replace("[", "").replace("]", "").replace("\'", "").split()
    model = model_from_json(json_strings[0])
    model.load_weights("last.hdf5")  # best.hdf5 で損失最小のパラメータを使用
    img = load_img(imgname, target_size=(hw["height"], hw["width"]))    
    TEST = img_to_array(img) / 255
    
    pred = model.predict(np.array([TEST]), batch_size=1, verbose=0)
    
    img = imgname.split("/")
    picture = img[1]
    gomi = img[2]
    
    Path = './picture2/' + picture
    
    Class = textlist[np.argmax(pred)].replace(",", "")
    
    print(Path)
    
    #Classに応じて画像をそれぞれのフォルダーに分類
    if Class == "soeda":
        shutil.copyfile(Path, './../../../Google ドライブ/soeda/' + picture)
    elif Class == "kaoru":
        shutil.copyfile(Path, './../../../Google ドライブ/kaoru/' + picture)
    elif Class == "kasuya":
        shutil.copyfile(Path, './../../../Google ドライブ/kasuya/' + picture)
    elif Class == "reiya":
        shutil.copyfile(Path, './../../../Google ドライブ/reiya/' + picture)
    elif Class == "mattyan":
        shutil.copyfile(Path, './../../../Google ドライブ/mattyan/' + picture)
    elif Class == "gomi":
        shutil.copyfile(imgname, './gomi/' + gomi)
    else:
        print("該当無し")
    
    
    print(">> 計算結果↓\n" + str(pred))
    print(">> この画像（"+ imgname +"）は「" + Class + "」です。")
    
    return np.argmax(pred)

# %%
import os.path as op

i = 0
for filename in FileNames :
    # ディレクトリ名入力
    while True :
        dirname = input(">>「" + ClassNames[i] + "」の画像のあるディレクトリ ： ")
        if op.isdir(dirname) :
            break
        print(">> そのディレクトリは存在しません！")

    # 関数実行
    PreProcess(dirname, filename, var_amount=3)
    i += 1
    print("¥")
    #img/kaoruO
    #img/soedaO
    #img/reiyaO
    #img/mattyanO
    #img/kasuyaO
# Out:
# >>「gomi」の画像のあるディレクトリ ： img/gomi
# >> img/gomiから6801個のファイル読み込み成功
# ¥
# >>「kaoru」の画像のあるディレクトリ ： img/kaoru
# >> img/kaoruから273個のファイル読み込み成功
# ¥
# >>「soeda」の画像のあるディレクトリ ： img/soeda
# >> img/soedaから249個のファイル読み込み成功
# ¥
# >>「reiya」の画像のあるディレクトリ ： img/reiya
# >> img/reiyaから224個のファイル読み込み成功
# ¥
# >>「mattyan」の画像のあるディレクトリ ： img/mattyan
# >> img/mattyanから377個のファイル読み込み成功
# ¥
# >>「kasuya」の画像のあるディレクトリ ： img/kasuya
# >> img/kasuyaから286個のファイル読み込み成功
# ¥

# %%
# 関数実行
Learning(tsnum=10, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (24630, 32, 32, 3)
# >> 学習開始
# Train on 24570 samples, validate on 60 samples
# Epoch 1/50
# 24570/24570 [==============================] - 1200s 49ms/step - loss: 0.5503 - acc: 0.8496 - val_loss: 2.0604 - val_acc: 0.2667
#
# Epoch 00001: val_loss improved from inf to 2.06039, saving model to best.hdf5
# Epoch 2/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.4174 - acc: 0.8786 - val_loss: 1.8656 - val_acc: 0.3667
#
# Epoch 00002: val_loss improved from 2.06039 to 1.86555, saving model to best.hdf5
# Epoch 3/50
# 24570/24570 [==============================] - 1187s 48ms/step - loss: 0.3604 - acc: 0.8926 - val_loss: 1.6343 - val_acc: 0.3667
#
# Epoch 00003: val_loss improved from 1.86555 to 1.63426, saving model to best.hdf5
# Epoch 4/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.3280 - acc: 0.9038 - val_loss: 1.4429 - val_acc: 0.4667
#
# Epoch 00004: val_loss improved from 1.63426 to 1.44288, saving model to best.hdf5
# Epoch 5/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.3015 - acc: 0.9133 - val_loss: 1.4665 - val_acc: 0.5333
#
# Epoch 00005: val_loss did not improve from 1.44288
# Epoch 6/50
# 24570/24570 [==============================] - 1187s 48ms/step - loss: 0.2834 - acc: 0.9169 - val_loss: 1.2227 - val_acc: 0.5167
#
# Epoch 00006: val_loss improved from 1.44288 to 1.22273, saving model to best.hdf5
# Epoch 7/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.2620 - acc: 0.9227 - val_loss: 1.3668 - val_acc: 0.4167
#
# Epoch 00007: val_loss did not improve from 1.22273
# Epoch 8/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.2406 - acc: 0.9277 - val_loss: 1.2355 - val_acc: 0.5000
#
# Epoch 00008: val_loss did not improve from 1.22273
# Epoch 9/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.2323 - acc: 0.9302 - val_loss: 1.3757 - val_acc: 0.5333
#
# Epoch 00009: val_loss did not improve from 1.22273
# Epoch 10/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.2142 - acc: 0.9357 - val_loss: 1.5290 - val_acc: 0.5000
#
# Epoch 00010: val_loss did not improve from 1.22273
# Epoch 11/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.2068 - acc: 0.9384 - val_loss: 1.5081 - val_acc: 0.4833
#
# Epoch 00011: val_loss did not improve from 1.22273
# Epoch 12/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.1945 - acc: 0.9409 - val_loss: 1.3149 - val_acc: 0.5500
#
# Epoch 00012: val_loss did not improve from 1.22273
# Epoch 13/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1840 - acc: 0.9444 - val_loss: 1.4472 - val_acc: 0.5667
#
# Epoch 00013: val_loss did not improve from 1.22273
# Epoch 14/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1748 - acc: 0.9459 - val_loss: 1.3799 - val_acc: 0.5667
#
# Epoch 00014: val_loss did not improve from 1.22273
# Epoch 15/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.1699 - acc: 0.9488 - val_loss: 1.3691 - val_acc: 0.5333
#
# Epoch 00015: val_loss did not improve from 1.22273
# Epoch 16/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1588 - acc: 0.9504 - val_loss: 1.3305 - val_acc: 0.6333
#
# Epoch 00016: val_loss did not improve from 1.22273
# Epoch 17/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1561 - acc: 0.9523 - val_loss: 1.2748 - val_acc: 0.6000
#
# Epoch 00017: val_loss did not improve from 1.22273
# Epoch 18/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.1499 - acc: 0.9542 - val_loss: 1.3231 - val_acc: 0.6667
#
# Epoch 00018: val_loss did not improve from 1.22273
# Epoch 19/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1447 - acc: 0.9544 - val_loss: 1.4086 - val_acc: 0.6167
#
# Epoch 00019: val_loss did not improve from 1.22273
# Epoch 20/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1366 - acc: 0.9564 - val_loss: 1.4417 - val_acc: 0.6000
#
# Epoch 00020: val_loss did not improve from 1.22273
# Epoch 21/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1332 - acc: 0.9567 - val_loss: 1.3517 - val_acc: 0.6333
#
# Epoch 00021: val_loss did not improve from 1.22273
# Epoch 22/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1287 - acc: 0.9598 - val_loss: 1.4637 - val_acc: 0.6000
#
# Epoch 00022: val_loss did not improve from 1.22273
# Epoch 23/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1298 - acc: 0.9594 - val_loss: 1.4391 - val_acc: 0.6000
#
# Epoch 00023: val_loss did not improve from 1.22273
# Epoch 24/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1262 - acc: 0.9603 - val_loss: 1.3288 - val_acc: 0.6667
#
# Epoch 00024: val_loss did not improve from 1.22273
# Epoch 25/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.1248 - acc: 0.9605 - val_loss: 1.3634 - val_acc: 0.6333
#
# Epoch 00025: val_loss did not improve from 1.22273
# Epoch 26/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1180 - acc: 0.9625 - val_loss: 1.3442 - val_acc: 0.6667
#
# Epoch 00026: val_loss did not improve from 1.22273
# Epoch 27/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1222 - acc: 0.9618 - val_loss: 1.3302 - val_acc: 0.6167
#
# Epoch 00027: val_loss did not improve from 1.22273
# Epoch 28/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1170 - acc: 0.9626 - val_loss: 1.3061 - val_acc: 0.6500
#
# Epoch 00028: val_loss did not improve from 1.22273
# Epoch 29/50
# 24570/24570 [==============================] - 1191s 48ms/step - loss: 0.1124 - acc: 0.9643 - val_loss: 1.3136 - val_acc: 0.6667
#
# Epoch 00029: val_loss did not improve from 1.22273
# Epoch 30/50
# 24570/24570 [==============================] - 1191s 48ms/step - loss: 0.1084 - acc: 0.9659 - val_loss: 1.3695 - val_acc: 0.6667
#
# Epoch 00030: val_loss did not improve from 1.22273
# Epoch 31/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1094 - acc: 0.9642 - val_loss: 1.3015 - val_acc: 0.6833
#
# Epoch 00031: val_loss did not improve from 1.22273
# Epoch 32/50
# 24570/24570 [==============================] - 1191s 48ms/step - loss: 0.1122 - acc: 0.9641 - val_loss: 1.3258 - val_acc: 0.6833
#
# Epoch 00032: val_loss did not improve from 1.22273
# Epoch 33/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1083 - acc: 0.9656 - val_loss: 1.2991 - val_acc: 0.7167
#
# Epoch 00033: val_loss did not improve from 1.22273
# Epoch 34/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1097 - acc: 0.9647 - val_loss: 1.2996 - val_acc: 0.7000
#
# Epoch 00034: val_loss did not improve from 1.22273
# Epoch 35/50
# 24570/24570 [==============================] - 1191s 48ms/step - loss: 0.1027 - acc: 0.9667 - val_loss: 1.2948 - val_acc: 0.7167
#
# Epoch 00035: val_loss did not improve from 1.22273
# Epoch 36/50
# 24570/24570 [==============================] - 1191s 48ms/step - loss: 0.1064 - acc: 0.9652 - val_loss: 1.3062 - val_acc: 0.6833
#
# Epoch 00036: val_loss did not improve from 1.22273
# Epoch 37/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.1043 - acc: 0.9668 - val_loss: 1.3012 - val_acc: 0.7167
#
# Epoch 00037: val_loss did not improve from 1.22273
# Epoch 38/50
# 24570/24570 [==============================] - 1192s 48ms/step - loss: 0.1012 - acc: 0.9679 - val_loss: 1.3141 - val_acc: 0.7000
#
# Epoch 00038: val_loss did not improve from 1.22273
# Epoch 39/50
# 24570/24570 [==============================] - 1193s 49ms/step - loss: 0.1048 - acc: 0.9670 - val_loss: 1.2798 - val_acc: 0.7000
#
# Epoch 00039: val_loss did not improve from 1.22273
# Epoch 40/50
# 24570/24570 [==============================] - 1191s 48ms/step - loss: 0.1040 - acc: 0.9671 - val_loss: 1.2951 - val_acc: 0.6833
#
# Epoch 00040: val_loss did not improve from 1.22273
# Epoch 41/50
# 24570/24570 [==============================] - 1192s 49ms/step - loss: 0.1016 - acc: 0.9661 - val_loss: 1.2696 - val_acc: 0.6833
#
# Epoch 00041: val_loss did not improve from 1.22273
# Epoch 42/50
# 24570/24570 [==============================] - 1187s 48ms/step - loss: 0.1041 - acc: 0.9669 - val_loss: 1.2843 - val_acc: 0.6833
#
# Epoch 00042: val_loss did not improve from 1.22273
# Epoch 43/50
# 24570/24570 [==============================] - 1187s 48ms/step - loss: 0.1022 - acc: 0.9670 - val_loss: 1.3108 - val_acc: 0.6833
#
# Epoch 00043: val_loss did not improve from 1.22273
# Epoch 44/50
# 24570/24570 [==============================] - 1188s 48ms/step - loss: 0.1029 - acc: 0.9673 - val_loss: 1.3303 - val_acc: 0.6833
#
# Epoch 00044: val_loss did not improve from 1.22273
# Epoch 45/50
# 24570/24570 [==============================] - 1187s 48ms/step - loss: 0.1029 - acc: 0.9682 - val_loss: 1.3159 - val_acc: 0.7000
#
# Epoch 00045: val_loss did not improve from 1.22273
# Epoch 46/50
# 24570/24570 [==============================] - 1187s 48ms/step - loss: 0.1000 - acc: 0.9676 - val_loss: 1.3069 - val_acc: 0.7000
#
# Epoch 00046: val_loss did not improve from 1.22273
# Epoch 47/50
# 24570/24570 [==============================] - 1189s 48ms/step - loss: 0.0997 - acc: 0.9672 - val_loss: 1.2820 - val_acc: 0.7000
#
# Epoch 00047: val_loss did not improve from 1.22273
# Epoch 48/50
# 24570/24570 [==============================] - 1191s 48ms/step - loss: 0.0994 - acc: 0.9678 - val_loss: 1.2810 - val_acc: 0.7000
#
# Epoch 00048: val_loss did not improve from 1.22273
# Epoch 49/50
# 24570/24570 [==============================] - 1187s 48ms/step - loss: 0.0993 - acc: 0.9683 - val_loss: 1.3043 - val_acc: 0.7000
#
# Epoch 00049: val_loss did not improve from 1.22273
# Epoch 50/50
# 24570/24570 [==============================] - 1190s 48ms/step - loss: 0.0996 - acc: 0.9683 - val_loss: 1.2973 - val_acc: 0.7000
#
# Epoch 00050: val_loss did not improve from 1.22273
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-880dc56b9726> in <module>()
#       1 # 関数実行
# ----> 2 Learning(tsnum=10, nb_epoch=50, batch_size=8, learn_schedule=0.9)
#
# <ipython-input-8-63311826b172> in Learning(tsnum, nb_epoch, batch_size, learn_schedule)
#     136
#     137     #acc, val_accのプロット
# --> 138     plt.plot(hist.history["acc"], label="acc", ls="-", marker="o")
#     139     plt.plot(hist.history["val_acc"], label="val_acc", ls="-", marker="x")
#     140     plt.ylabel("accuracy")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### 単発

# %%
import os.path as op

while True:
    while True:
        imgname = input("\n>> 入力したい画像ファイル(「END」で終了) ： ")
        if op.isfile(imgname) or imgname == "END":
            break
        print(">> そのファイルは存在しません！")
    if imgname == "END":
        break

    # 関数実行
    TestProcess(imgname)
    
    #test/reiya/IMG_0995.jpg

# %% [markdown]
# ### 連発

# %%
dirname = "out_picture2"#input("フォルダ名：")
files = glob.glob(dirname + "/*/*.jpg")
cn1 = 0; cn2 = 0;
for imgname in files :
    kind = TestProcess(imgname)
    if kind == 1:
        cn2 += 1
    cn1 += 1

    #print(files)
print("学習・非学習含め正答率は" + str(cn2*1.0/cn1) + "です。")
# Out:
# ./picture2/DSC_0173.JPG
# >> 計算結果↓
# [[3.6555839e-08 5.0864380e-04 1.9256660e-05 4.5833708e-04 9.9847633e-01
#   5.3739682e-04]]
# >> この画像（out_picture2/DSC_0173.JPG/out_(DSC_0173.JPG)4.jpg）は「mattyan」です。
# ./picture2/DSC_0957.JPG
# >> 計算結果↓
# [[3.8141877e-07 9.9856049e-01 1.1702053e-04 3.4924084e-04 2.4702353e-04
#   7.2589022e-04]]
# >> この画像（out_picture2/DSC_0957.JPG/out_(DSC_0957.JPG)10.jpg）は「kaoru」です。
# ./picture2/DSC_0957.JPG
# >> 計算結果↓
# [[1.0000000e+00 4.5653308e-09 4.8208584e-08 1.1725707e-08 3.1915048e-10
#   4.6425672e-10]]
# >> この画像（out_picture2/DSC_0957.JPG/out_(DSC_0957.JPG)11.jpg）は「gomi」です。
# ./picture2/DSC_0957.JPG
# >> 計算結果↓
# [[3.0795280e-05 9.0187008e-05 9.9586970e-01 1.3028311e-04 3.5478105e-04
#   3.5243130e-03]]
# >> この画像（out_picture2/DSC_0957.JPG/out_(DSC_0957.JPG)21.jpg）は「soeda」です。
# ./picture2/DSC_0957.JPG
# >> 計算結果↓
# [[2.7079109e-04 1.5494004e-01 1.0229335e-02 3.8832930e-04 4.9004483e-04
#   8.3368146e-01]]
# >> この画像（out_picture2/DSC_0957.JPG/out_(DSC_0957.JPG)9.jpg）は「kasuya」です。
# ./picture2/IMG_0228.JPG
# >> 計算結果↓
# [[3.0705510e-04 9.9625385e-01 5.4883596e-04 1.2306264e-03 4.6132580e-05
#   1.6135109e-03]]
# >> この画像（out_picture2/IMG_0228.JPG/out_(IMG_0228.JPG)5.jpg）は「kaoru」です。
# ./picture2/IMG_0321.JPG
# >> 計算結果↓
# [[4.2854372e-04 8.4869111e-01 2.1171471e-02 4.3592378e-02 4.5085335e-03
#   8.1607915e-02]]
# >> この画像（out_picture2/IMG_0321.JPG/out_(IMG_0321.JPG)1.jpg）は「kaoru」です。
# ./picture2/IMG_0321.JPG
# >> 計算結果↓
# [[1.0000000e+00 5.3829630e-15 4.7348193e-14 6.6692706e-15 3.0197329e-13
#   5.8186395e-15]]
# >> この画像（out_picture2/IMG_0321.JPG/out_(IMG_0321.JPG)2.jpg）は「gomi」です。
# ./picture2/IMG_0321.JPG
# >> 計算結果↓
# [[9.9946743e-01 3.9169052e-05 2.6311722e-04 1.3614453e-05 2.0216923e-04
#   1.4580512e-05]]
# >> この画像（out_picture2/IMG_0321.JPG/out_(IMG_0321.JPG)3.jpg）は「gomi」です。
# ./picture2/IMG_0321.JPG
# >> 計算結果↓
# [[9.9920553e-01 2.0517423e-04 3.7533918e-04 9.3413721e-05 7.3564734e-05
#   4.6925699e-05]]
# >> この画像（out_picture2/IMG_0321.JPG/out_(IMG_0321.JPG)4.jpg）は「gomi」です。
# ./picture2/IMG_0321.JPG
# >> 計算結果↓
# [[9.9941695e-01 6.9425259e-05 1.4395019e-04 1.3735522e-04 1.5673091e-04
#   7.5585835e-05]]
# >> この画像（out_picture2/IMG_0321.JPG/out_(IMG_0321.JPG)5.jpg）は「gomi」です。
# ./picture2/IMG_0716.JPG
# >> 計算結果↓
# [[9.9717015e-01 4.1952168e-04 1.6995337e-03 2.0022994e-04 2.7805456e-04
#   2.3251836e-04]]
# >> この画像（out_picture2/IMG_0716.JPG/out_(IMG_0716.JPG)1.jpg）は「gomi」です。
# ./picture2/IMG_0716.JPG
# >> 計算結果↓
# [[9.9970764e-01 3.2200049e-05 8.6112479e-05 3.6565394e-05 1.1033255e-04
#   2.7122191e-05]]
# >> この画像（out_picture2/IMG_0716.JPG/out_(IMG_0716.JPG)2.jpg）は「gomi」です。
# ./picture2/IMG_0716.JPG
# >> 計算結果↓
# [[9.9973541e-01 3.7913553e-05 2.1982235e-04 1.2062732e-06 2.9758728e-06
#   2.7764015e-06]]
# >> この画像（out_picture2/IMG_0716.JPG/out_(IMG_0716.JPG)3.jpg）は「gomi」です。
# ./picture2/IMG_0716.JPG
# >> 計算結果↓
# [[9.9987435e-01 1.5234175e-05 2.9901601e-05 2.7808195e-05 4.5803343e-05
#   6.8868849e-06]]
# >> この画像（out_picture2/IMG_0716.JPG/out_(IMG_0716.JPG)4.jpg）は「gomi」です。
# ./picture2/IMG_0716.JPG
# >> 計算結果↓
# [[9.
]
# >> この画像（out_picture2/IMG_2514.JPG/out_(IMG_2514.JPG)8.jpg）は「gomi」です。
# ./picture2/IMG_2514.JPG
# >> 計算結果↓
# [[9.9973077e-01 1.8817633e-04 2.7278695e-05 2.7350332e-05 6.1076385e-06
#   2.0348449e-05]]
# >> この画像（out_picture2/IMG_2514.JPG/out_(IMG_2514.JPG)9.jpg）は「gomi」です。
# ./picture2/IMG_3140.JPG
# >> 計算結果↓
# [[2.30715843e-04 1.00448751e-03 4.97607529e-01 8.39070752e-02
#   1.32009005e-02 4.04049277e-01]]
# >> この画像（out_picture2/IMG_3140.JPG/out_(IMG_3140.JPG)10.jpg）は「soeda」です。
# ./picture2/IMG_3140.JPG
# >> 計算結果↓
# [[9.9983037e-01 1.9098206e-05 4.0158295e-05 3.4457022e-05 4.2797194e-05
#   3.3080032e-05]]
# >> この画像（out_picture2/IMG_3140.JPG/out_(IMG_3140.JPG)7.jpg）は「gomi」です。
# ./picture2/IMG_3140.JPG
# >> 計算結果↓
# [[1.8449327e-04 5.7061100e-01 8.9183776e-04 4.2810032e-01 1.5283897e-05
#   1.9710312e-04]]
# >> この画像（out_picture2/IMG_3140.JPG/out_(IMG_3140.JPG)8.jpg）は「kaoru」です。
# ./picture2/IMG_3140.JPG
# >> 計算結果↓
# [[9.9670225e-01 3.7222129e-04 8.5976959e-04 1.5607624e-03 2.4824517e-04
#   2.5666913e-04]]
# >> この画像（out_picture2/IMG_3140.JPG/out_(IMG_3140.JPG)9.jpg）は「gomi」です。
# ./picture2/IMG_3355.JPG
# >> 計算結果↓
# [[1.2627236e-02 1.4375812e-01 2.8945387e-03 2.5725046e-01 3.2661622e-04
#   5.8314306e-01]]
# >> この画像（out_picture2/IMG_3355.JPG/out_(IMG_3355.JPG)5.jpg）は「kasuya」です。
# ./picture2/IMG_7011.JPG
# >> 計算結果↓
# [[4.3135218e-04 3.6843417e-03 6.9651186e-01 2.0736276e-01 8.2377240e-02
#   9.6323993e-03]]
# >> この画像（out_picture2/IMG_7011.JPG/out_(IMG_7011.JPG)15.jpg）は「soeda」です。
# ./picture2/IMG_7011.JPG
# >> 計算結果↓
# [[1.0000000e+00 1.3091055e-08 1.4108518e-09 1.5528283e-09 2.3152536e-08
#   5.6963029e-10]]
# >> この画像（out_picture2/IMG_7011.JPG/out_(IMG_7011.JPG)16.jpg）は「gomi」です。
# ./picture2/IMG_7011.JPG
# >> 計算結果↓
# [[1.0000000e+00 1.6836776e-12 2.6732005e-11 4.2417602e-12 3.5681206e-12
#   1.0204817e-12]]
# >> この画像（out_picture2/IMG_7011.JPG/out_(IMG_7011.JPG)17.jpg）は「gomi」です。
# ./picture2/IMG_9635.JPG
# >> 計算結果↓
# [[1.0000000e+00 1.5093218e-09 1.2179116e-08 1.1974772e-09 1.3199292e-08
#   9.7077735e-10]]
# >> この画像（out_picture2/IMG_9635.JPG/out_(IMG_9635.JPG)1.jpg）は「gomi」です。
# ./picture2/IMG_9635.JPG
# >> 計算結果↓
# [[1.0733304e-03 9.2318285e-01 1.0303731e-02 5.3228043e-02 3.6444521e-04
#   1.1847556e-02]]
# >> この画像（out_picture2/IMG_9635.JPG/out_(IMG_9635.JPG)2.jpg）は「kaoru」です。
# ./picture2/IMG_9635.JPG
# >> 計算結果↓
# [[9.9966574e-01 1.2740571e-05 1.4314920e-04 2.3083685e-05 1.4597410e-04
#   9.2687142e-06]]
# >> この画像（out_picture2/IMG_9635.JPG/out_(IMG_9635.JPG)3.jpg）は「gomi」です。
# ./picture2/IMG_9635.JPG
# >> 計算結果↓
# [[9.9999309e-01 1.0096475e-06 2.2479703e-06 3.8606547e-07 8.8117957e-07
#   2.3077671e-06]]
# >> この画像（out_picture2/IMG_9635.JPG/out_(IMG_9635.JPG)4.jpg）は「gomi」です。
# ./picture2/IMG_9635.JPG
# >> 計算結果↓
# [[9.9998844e-01 7.5152735e-07 8.2542792e-06 9.6429756e-07 1.3772727e-06
#   3.2590717e-07]]
# >> この画像（out_picture2/IMG_9635.JPG/out_(IMG_9635.JPG